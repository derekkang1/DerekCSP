# %% [raw]
# ---
# layout: post
# title: Project Overview and Unique Contributions
# type: issues
# comments: true
# ---

# %% [markdown]
# # Engineering & Technical Portfolio
#
# Derek Kang --- Del Norte High School Class of 2027
#
# ---
#
# ## CAD & Mechanical Design
#
# ### FTC Robot – Full Robot Assembly
# *FIRST Tech Challenge · Onshape*
#
# Designed and modeled the full robot assembly for our FTC team's competition season. The model covers the drive train, intake mechanism, arm linkage, and end effector — all modeled with real-world tolerances and assembly constraints to enable rapid physical iteration.
#
# <img src="{{site.baseurl}}/images/portfolio/cad1.png"/>
#
# <img src="{{site.baseurl}}/images/portfolio/cad2.png"/>
#
# <img src="{{site.baseurl}}/images/portfolio/cad3.png"/>
#
# <img src="{{site.baseurl}}/images/portfolio/cad4.png"/>
#
# Focused on modularity: each subsystem was designed as a self-contained assembly so mechanisms could be swapped between matches without a full teardown.
#
# <img src="{{site.baseurl}}/images/portfolio/cad5.png"/>
#
# <img src="{{site.baseurl}}/images/portfolio/cad6.png"/>
# <img src="{{site.baseurl}}/images/portfolio/cad7.png"/>
# <img src="{{site.baseurl}}/images/portfolio/cad8.png"/>
# <img src="{{site.baseurl}}/images/portfolio/cad9.png"/>
#
# **Skills:** Onshape · Full Assembly · Drive Train · Toleranced Parts
#
# ---
#
# ### Science Olympiad – Engineering CAD Event
# *Science Olympiad · Onshape*
#
# Produced the CAD model for my Science Olympiad engineering event entry. The model was used both as a design reference during construction and as a competition deliverable, requiring detailed annotation, accurate mass estimates, and clear part breakdowns.
#
# Constrained by event rules limiting materials and weight — the CAD process helped identify over-designed sections before cutting any material.
#
# **Skills:** Onshape · Structural Analysis · Mass Estimation · Annotated Drawings
#
# ---
#
# ## Software Development
#
# ### Personal Blog & Developer Site(This site)
# *Jekyll · GitHub Pages · Markdown*
#
# Built and maintain a technical blog documenting projects, CS concepts, and coursework reflections. Hosted on GitHub Pages, with content authored in Markdown and a customized Jekyll theme.
#
# **Skills:** Jekyll · GitHub Pages · HTML/CSS · Markdown
#
# ---
#
# ### OCS GitHub Analytics & Grade Predictor
# *AP Computer Science A · Backend Engineer · Flask · GitHub GraphQL API · JWT Auth*
#
# Expanded the Open Coding Society dashboard into a richer analytics platform. As backend engineer, I tested and hardened all existing analytics endpoints in Postman, standardized admin routes to `GET` for REST consistency, and added line-change metrics to the commit stats model.
#
# **My contributions:**
# - Tested all analytics API endpoints end-to-end via Postman and frontend integration
# - Converted admin endpoints from `POST` to `GET` for REST compliance
# - Extended the commit stats function to also return per-commit line additions, deletions, and net totals — giving a more complete picture of contribution volume
# - Built an admin frontend panel that looks up any user's commits by UID and renders them as linked commit cards
# - Integrated with the OCS dashboard merge, coordinating with peer grade-analytics groups
#
# The result was a significantly more useful dashboard: instructors can drill into any student's commit history at a glance, and the grade predictor now accounts for code volume in addition to commit count.
#
# <img src="{{site.baseurl}}/images/final2.png"/>
#
# ![Admin commit panel](https://github.com/user-attachments/assets/70087575-5e5c-40db-91cb-83c1f8a1c0aa)
#
# <img src="{{site.baseurl}}/images/final1.png"/>
#
# **Skills:** Python · Flask · GitHub GraphQL · JWT · REST API · Postman
#
# ---
#
# ### InterTravel – Budget Brilliance Module
# *AP Computer Science A · Full-Stack · Flask · SQLAlchemy · JavaScript*
#
# Built the budgeting subsystem for a group travel-planner app serving 5 international cities. Users enter a trip budget, lock in known expenses, then allocate remaining funds across categories. The system persists entries per user to a backend database and updates the remaining-budget display in real time.
#
# The app was fully deployed with working login, a live backend, and a public frontend. I owned the entire budgeting vertical — from the database model through the API through the frontend table and remaining-balance display.
#
# I built the full budgeting vertical — database model, JWT-secured CRUD API, and the frontend table with a live remaining-budget counter. The API persists each user's expense entries to a backend database and the frontend fetches and re-renders the table after every change. I also integrated a currency converter API so users could budget in their local currency, and customized the Flask admin backend UI to reflect the InterTravel brand.
#
# <img src="{{site.baseurl}}/images/final3.png"/>
# <img src="{{site.baseurl}}/images/tri2final/remainingbudget.png"/>
#
# <img src="{{site.baseurl}}/images/tri2final/backendwebsite.png"/>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/qWp4kdXQ5iU" frameborder="0" allowfullscreen></iframe>
#
# [Or watch the video here!](https://www.youtube.com/watch?v=qWp4kdXQ5iU)
#
# **Skills:** Python · Flask · SQLAlchemy · JavaScript · JWT Auth · CRUD · REST API · Full-Stack
#
# ---
#
# ## Science Fair
#
# ### [Your Project Title]
# *Electronics · Experimental Research*
#
# <img src="{{site.baseurl}}/images/portfolio/fair4.png"/>
# <img src="{{site.baseurl}}/images/portfolio/fair3.png"/>
#
# [Add a brief description of your science fair project here — what problem you investigated, the hypothesis, and what electronic components or circuits you designed and built.]
#
# [Describe your key finding or result.]
#
# **What I built:**
# - [Key component or circuit you designed]
# - [Measurement or data collection method]
# - [Result or conclusion]
#
# <img src="{{site.baseurl}}/images/portfolio/fair1.png"/>
# <img src="{{site.baseurl}}/images/portfolio/fair2.png"/>
#
# **Skills:** [Microcontroller / sensor] · Electronics · Experimental Design
#
# ---
#
# ## MAP Research – Teleoperation
#
# ### [Your Research Title]
# *Mentored Advanced Project · Human–Robot Interaction*
#
# [Describe your MAP research project — the research question, why teleoperation matters, and the approach you took.]
#
# [Key insight or finding — one to two sentences.]
#
# <img src="{{site.baseurl}}/images/portfolio/map1.png"/>
#
# **Research areas:**
# - [Method or literature you engaged with]
# - [Any prototype, experiment, or analysis you conducted]
# - [Conclusion or open question your research surfaced]
#
# Teleoperation is directly relevant to RobotX: maritime surface vehicles operating in complex, GPS-degraded environments rely on robust human-in-the-loop interfaces, latency compensation, and situational awareness — all areas this research speaks to.
#
# <img src="{{site.baseurl}}/images/portfolio/map2.png"/>
#
# **Skills:** Teleoperation · Human–Robot Interaction · Control Systems · Research

# %% [markdown]
# # InterTravel
# ### Group’s purpose
# We wanted to create a travel planner with a varities of functions for the user: “To make a budget-friendly travel planner that will allow users to find activities, hotels, restaurants, and much more.”
#
# This project was depolyed and had working log in systems, as well as a backend site.
#
# It would include info for 5 different cities (planned):
# - Paris (only one integrated)
# - Hong Kong
# - New York
# - Mumbai
# - London
#
# It would include these functionalities:
# - Activity Planner: users can search for activities in the city they are visiting and ask questions to a chatbot for help.
# - Lodging Listings: users can search for hotels in their city and give them a star rating.
# - Packing Portal: users can select which items to carry with them while travelling.
# - Cuisine Chronicles: users can view the menu of restaurants and give reviews.
# - Fair Fares: users can search for flights to and from their destination and compare prices.
# - Budget Brilliance: users can set their budget for the trip and see suggestions.
# - Wellness waypoints: users can search for hospitals in their area in the case of an emergency.
#
# ### My contributions
# I built a section of the website that helps the user plan their travel budget with functional and user-friendly frontend and dynamically updating APIs that connect to the backend. It will include these planned features.
# - Budget Plan Assister:
#   - takes in user inputed location, budget and any hard set attractions or travel items with predetermined price, user can then also input what they need help with finding (ex. hotels)
#   - Outputs budget entries into a nice table with clear depictions, and also the remaining budget
#   - integrates smoothly into the overall daily planning system. The user should be able to add budgeting concerns and details to their daily itinerary and travel plan
#   - currency converter API
#
# <img src="{{site.baseurl}}/images/final3.png"/>
# <img src="{{site.baseurl}}/images/tri2final/remainingbudget.png"/>
#
# ## Slient Video Demo
# <iframe width="560" height="315" src="https://www.youtube.com/embed/qWp4kdXQ5iU" frameborder="0" allowfullscreen></iframe>
#
# [Or watch the video here!](https://www.youtube.com/watch?v=qWp4kdXQ5iU)
#
# ## Dynamic Budgeting API with CRUD and backend database
#
# ```py
# import jwt
# from flask import Blueprint, request, jsonify, g
# from flask_restful import Api, Resource
# from flask_cors import CORS, cross_origin
# from datetime import datetime
# from __init__ import app, db  # Ensure db is imported
# from api.jwt_authorize import token_required
# from model.budgeting import Budgeting  # Assuming your Budgeting model is in the 'budgeting' module
# from model.user import User
#
# budgeting_api = Blueprint('budgeting_api', __name__, url_prefix='/api')
# CORS(budgeting_api, supports_credentials=True, methods=["GET", "POST", "PUT", "DELETE"])
# api = Api(budgeting_api)
#
# class BudgetingAPI:
#     """
#     Define the API CRUD endpoints for the Budgeting model.
#     Operations include creating, retrieving, updating, and deleting budgeting entries.
#     """
#
#     class _CRUD(Resource):
#         @token_required()
#         @cross_origin(supports_credentials=True)
#         def post(self):
#             current_user = g.current_user
#             data = request.get_json()
#
#             if not data or 'expense' not in data or 'cost' not in data or 'category' not in data:
#                 return jsonify({"message": "Expense, cost, and category are required"}), 400
#
#             budgeting = Budgeting(
#                 expense=data.get('expense'),
#                 cost=data.get('cost'),
#                 category=data.get('category'),
#                 user_id=current_user.id
#             )
#
#             db.session.add(budgeting)
#             db.session.commit()
#
#             return jsonify({"message": "Budgeting entry created successfully"})
#
#         @token_required()
#         def get(self):
#             current_user = g.current_user
#             budgeting_entries = Budgeting.query.filter_by(user_id=current_user.id).all()
#             return jsonify([entry.read() for entry in budgeting_entries])
#
#         @token_required()
#         def put(self):
#             current_user = g.current_user
#             data = request.get_json()
#             budgeting_id = data.get('id')
#
#             if not budgeting_id:
#                 return jsonify({"message": "ID is required for updating a budgeting entry"}), 400
#
#             budgeting = Budgeting.query.filter_by(id=budgeting_id, user_id=current_user.id).first()
#             if not budgeting:
#                 return jsonify({"message": "Budgeting entry not found"}), 404
#
#             budgeting.expense = data.get('expense', budgeting.expense)
#             budgeting.cost = data.get('cost', budgeting.cost)
#             budgeting.category = data.get('category', budgeting.category)
#
#             db.session.commit()
#             return jsonify({"message": "Budgeting entry updated successfully"})
#
#         @token_required()
#         def delete(self):
#             current_user = g.current_user
#             data = request.get_json()
#             budgeting_id = data.get('id')
#
#             if not budgeting_id:
#                 return jsonify({"message": "ID is required for deleting a budgeting entry"}), 400
#
#             budgeting = Budgeting.query.filter_by(id=budgeting_id, user_id=current_user.id).first()
#             if not budgeting:
#                 return jsonify({"message": "Budgeting entry not found"}), 404
#
#             db.session.delete(budgeting)
#             db.session.commit()
#             return jsonify({"message": "Budgeting entry deleted successfully"})
#
# api.add_resource(BudgetingAPI._CRUD, '/budgeting')
# ```
# ```js
#     async function submitBudgeting(expense, cost, category) {
#         try {
#             const response = await fetch(`${pythonURI}/api/budgeting`, {
#                 ...fetchOptions,
#                 method: 'POST',
#                 headers: { 'Content-Type': 'application/json' },
#                 body: JSON.stringify({ expense, cost, category, user_id: USER_ID }),
#             });
#
#             if (response.ok) {
#                 createBudgetingTable();
#                 updateRemainingBudget();
#             } else {
#                 console.error('Failed to submit budgeting entry:', await response.json());
#             }
#         } catch (error) {
#             console.error("Error creating new budgeting entry:", error);
#         }
#     }
# ```
#
# ## Backend Admin role: customized backend UI to reflect our project with admin features
# <img src="{{site.baseurl}}/images/tri2final/backendwebsite.png"/>
# ```
# <div class="col-4">
#     <div class="card">
#         <img class="card-img-top" src="{{ url_for('static', filename='assets/airplane.jpg') }}" alt="Python Development" height="350">
#         <div class="card-body">
#         <h5 class="card-title">What are the features of <mark>InterTravel?</mark>?</h5>
#         <p class="card-text">
#             <ol>
#                 <li>Wellness Waypoints</li>
#                 <li>Lodging Listings</li>
#                 <li>Activity Planner</li>
#                 <li>Packing Portal</li>
#                 <li>Cuisine Chronicles</li>
#                 <li>Fair Fares</li>
#                 <li>Budget Brilliance</li>
#             </ol>
#         </p>
#         <a class="btn btn-primary" href="https://kiruthic-selvakumar.github.io/travel_frontend/">Check them out!</a>
#         </div>
#     </div>
# </div>
# ```
# ```
#   async function fetchBudgetingEntries() {
#     try {
#       const response = await fetch('/api/budgeting');
#       if (!response.ok) throw new Error('Failed to fetch budgeting entries');
#       const budgetingEntries = await response.json();
#       const budgetBody = document.getElementById('budgetBody');
#       budgetBody.innerHTML = '';
#       budgetingEntries.forEach(entry => {
#         budgetBody.innerHTML += `
#           <tr data-id="${entry.id}"
#               data-expense="${entry.expense}"
#               data-cost="${entry.cost}"
#               data-category="${entry.category}">
#             <td>${entry.id}</td>
#             <td>${entry.expense}</td>
#             <td>${entry.cost}</td>
#             <td>${entry.category}</td>
#             <td>
#               <button class="btn btn-primary edit-btn" data-id="${entry.id}">Edit</button>
#               <button class="btn btn-danger delete-btn" data-id="${entry.id}">Delete</button>
#             </td>
#           </tr>`;
#       });
#     } catch (error) {
#       console.error('Error fetching budgeting entries:', error);
#     }
#   }
# ```
